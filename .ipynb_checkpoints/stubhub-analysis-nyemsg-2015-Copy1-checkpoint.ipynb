# %%
import pandas as pd
import json
from pprint import pprint
import glob

# %%
def readStubHubJSON(inJSON):
    json_data=open(inJSON).read()
    data = json.loads(json_data)
    
    columns = ['scrapedatetime','showdate','totaltix','lowTicketPrice','lowWFees']
    df = pd.DataFrame(columns=columns) #create empty dataframe with fields
    
    totaltix       = data["eventTicketListing"]["totalTickets"]
    lowTicketPrice = data["eventTicketListing"]["eventTicket"][0]["cp"]
    lowTicketWFees = data["eventTicketListing"]["eventTicket"][0]["tc"]["amount"]
    #print totaltix, lowTicketPrice, lowTicketWFees
    x = [totaltix, lowTicketPrice, lowTicketWFees]
    return x

# %%
eventList = ['9394538', '9394539', '9394540', '9394541']
dateList  = ['20151230','20151231','20160101','20160102']

columns = ['datetime','showdate','totaltix','lowTicketPrice','lowTicketWFees']
df = pd.DataFrame(columns=columns) #create empty dataframe with fields
    
for date in dateList:
    
    totaltixList       = []
    lowTicketPriceList = []
    lowTicketWFeesList = []
    ticketData = []
    wd = 'data/'
    jsonFilesList = glob.glob(wd+'ph'+date+'*.json') #use glob * for ticketdate
    
    for jsonFile in jsonFilesList: 
        #print jsonFile
        ioJSON = jsonFile
        ticketData.append([jsonFile[24:32]+' '+jsonFile[32:34]+':'+jsonFile[34:36]]+[date]+readStubHubJSON(ioJSON))
        #print ticketData
    dfA = pd.DataFrame(ticketData) 
    dfA.columns = [columns]
    df = df.append([dfA])
    
print df.head(100)
# Out:
#           datetime  showdate  totaltix  lowTicketPrice  lowTicketWFees
# 0   20151002 14:53  20151230       218          125.00          148.50
# 1   20151002 14:58  20151230       218          125.00          148.50
# 2   20151002 15:17  20151230       224          110.00          133.95
# 3   20151002 19:17  20151230       254          125.00          148.50
# 4   20151002 23:17  20151230       264          119.99          145.64
# 5   20151003 03:17  20151230       264          119.99          145.64
# 6   20151003 07:17  20151230       264          119.99          145.64
# 7   20151003 11:17  20151230       270          119.99          145.64
# 8   20151003 15:17  20151230       272          119.99          145.64
# 9   20151003 19:17  20151230       271          119.99          145.64
# 10  20151003 23:17  20151230       276          117.99          143.30
# 11  20151004 03:17  20151230       276          117.99          143.30
# 12  20151004 07:17  20151230       275          117.99          143.30
# 0   20151002 14:54  20151231       580          184.00          220.53
# 1   20151002 14:59  20151231       580          184.00          220.53
# 2   20151002 16:17  20151231       630          175.00          207.00
# 3   20151002 20:17  20151231       676          174.99          209.99
# 4   20151003 00:17  20151231       701          177.99          210.50
# 5   20151003 04:17  20151231       708          176.71          209.00
# 6   20151003 08:17  20151231       707          176.71          209.00
# 7   20151003 12:17  20151231       717          176.71          209.00
# 8   20151003 16:17  20151231       717          173.99          208.82
# 9   20151003 20:17  20151231       715          173.99          208.82
# 10  20151004 00:17  20151231       719          173.99          208.82
# 11  20151004 04:17  20151231       718          173.99          208.82
# 12  20151004 08:17  20151231       717          179.99          212.84
# 0   20151002 14:54  20160101       340          120.00          145.65
# 1   20151002 15:00  20160101       341          120.00          145.65
# 2   20151002 17:17  20160101       384          120.00          145.65
# 3   20151002 21:17  20160101       426          124.00          147.33
# 4   20151003 01:17  20160101       435          124.00          147.33
# 5   20151003 05:17  20160101       434          124.00          147.33
# 6   20151003 09:17  20160101       435          124.00          147.33
# 7   20151003 13:17  20160101       432          120.00          145.65
# 8   20151003 17:17  20160101       423          120.00          145.65
# 9   20151003 21:17  20160101       423          124.00          147.33
# 10  20151004 01:17  20160101       427          124.00          147.33
# 11  20151004 05:17  20160101       428          124.00          147.33
# 12  20151004 09:17  20160101       427          124.00          147.33
# 0   20151002 14:54  20160102       415          120.50          143.24
# 1   20151002 15:01  20160102       415          120.50          143.24
# 2   20151002 18:17  20160102       446          123.00          149.16
# 3   20151002 22:17  20160102       475          123.00          149.16
# 4   20151003 02:17  20160102       474          123.00          149.16
# 5   20151003 06:17  20160102       474          119.00          141.48
# 6   20151003 10:17  20160102       474          120.00          142.65
# 7   20151003 14:17  20160102       473          120.00          142.65
# 8   20151003 18:17  20160102       482          110.69          131.76
# 9   20151003 22:17  20160102       482          113.88          138.49
# 10  20151004 02:17  20160102       481          120.00          142.65
# 11  20151004 06:17  20160102       480          120.00          142.65
# 12  20151004 10:17  20160102       480          120.00          142.65

# %%
# %matplotlib inline

from ggplot import *
from ggplot import aes
from ggplot import meat

df['Cost of Ticket ($ US)'] = df['lowTicketWFees']
df['show'] = df['showdate']
df['Time'] = pd.to_datetime(df['datetime'])


ggplot(aes(x='Time', y='Cost of Ticket ($ US)', colour='show'), data=df) + geom_line() \
+ ggtitle("NYEMSG Ticket Prices on StubHub") \
+ scale_x_date(labels='%b %d %y',breaks=date_breaks('day') ) \
+ geom_line(size=2.)
# Out:
# <ggplot: (290479853)>

# %%
theURL = 'https://dms2203.cartodb.com/api/v2/sql?filename=beh_walkability_ct2010.csv&format=csv&q=SELECT geoid,t10walkc FROM ct10 WHERE t10walkc <= 4 '

theFile = 'test2.csv'

import urllib
urllib.urlretrieve(theURL, theFile)

df = pd.read_csv(theFile)

#df

# %%
#print 'total tickets: ' + str(totaltix)
#print lowTicketPrice
#print lowTicketWFees

# "tc": {
#           "amount": 133.95,
#           "currency": "USD"
#         },
#         "fv": null,
#         "la": null,
#         "li": null,
#         "dm": null,
#         "dt": [
#           5
#         ],
#         "pm": {
#           "amount": 110,
#           "currency": "USD"
#         },
# Out:
# total tickets: 224
# 110.0
# 133.95
